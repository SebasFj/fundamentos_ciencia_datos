# %% [markdown]
# <img src="imgs\banner_fcd.jpg" alt="bannersp" width="1100"  height="150">

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>📦 Sesión práctica 2: Análisis Univariado, bivariado y multivariado</strong></span>
# ---
# <p align="right">
#   <a href="https://colab.research.google.com/#create=true" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/>
#   </a>
# </p>

# %% [markdown]
# ## <span style="color:black;"><strong>Datos del estudiante</strong></span>

# %%
nombre = input("📝 Ingresa tu nombre completo: ")
correo = input("📧 Ingresa tu correo electrónico: ")
cedula = input("🔢 Ingresa los últimos 6 dígitos de tu cédula: ")
# Out:
# 📝 Ingresa tu nombre completo: Sebastián Flórez Jaramillo
# 📧 Ingresa tu correo electrónico: sebastian.florezj@udea.edu.co
# 🔢 Ingresa los últimos 6 dígitos de tu cédula: 750946

# %% [markdown]
# ## <span style="color:black;"><strong>Parte 1: Análisis Univariado</strong></span>

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 1: Cálculo de medidas de tendencia central</strong></span>
#
# A partir de una muestra simulada de ingresos, calcula la **media, mediana y moda**, y luego a interpretarlas.
#
# 1. Usa el número base `528310` (debes reemplazarlo con los últimos 6 dígitos de tu documento de identificación).
# 2. Con este número genera una semilla (`np.random.seed`) para que los resultados sean reproducibles.
# 3. Los ingresos se simulan con una distribución normal:
#    - Media teórica: `(base % 10) + 2`
#    - Desviación estándar: `2`
#    - Tamaño de muestra: `30`
# 4. Los valores negativos se reemplazan por cero (pues los ingresos no pueden ser negativos).
# 5. Grafica tus resultados (ver imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e1.png" alt="sp_2_e1" width="900"  height="400">
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seed = 750946
np.random.seed(seed)
data = np.random.normal((seed % 10) + 2, 2, 100).round(1)

# %%
mean = np.mean(data)
median = np.median(data)
mode = np.bincount(data.astype(int)).argmax()

# %%
print(f"La media es: {mean}")
print(f"La mediana es: {median}")
print(f"La moda es: {mode}")
# Out:
# La media es: 8.478000000000002
# La mediana es: 8.25
# La moda es: 9

# %%
fig = plt.figure(figsize=(10, 5))
sns.histplot(data, bins=10,color="salmon", edgecolor="black", kde=True)
plt.title("Distribución de ingresos")
plt.xlabel("Ingresos")
plt.ylabel("Frecuencia")
plt.axvline()
plt.axvline(mean, color="blue", linestyle="--", linewidth=2, label=f"Media: {mean:.1f}")
plt.axvline(median, color="green", linestyle="-", linewidth=2, label=f"Mediana: {median}")
plt.axvline(mode, color="red", linestyle=":", linewidth=2, label=f"Moda: {mode}")
plt.legend()
plt.show()

# %% [markdown]
# # Interpretación:
#
# Media: Las personas pertenecientes a la base de datos tienen un ingreso promedio de 8.5 (unidades monetarias / unidad de tiempo).
#
# Mediana: Ordenando los datos ascendentemente, el dato de la mitad es 8.25.
#
# Moda: En la base de datos hay una cantidad mayor de personas con ingreso de 9 sobre todas las otras cantidades.

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 2: Cálculo de medidas de dispersión</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, analiza qué tan dispersos están los datos respecto a su media. Calcula:
# 1. Rango
# 2. Varianza
# 3. Desviación estándar
# 4. Coeficiente de variación
# 5. Genera una gráfica con los resultados obtenidos (ver imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e2.png" alt="sp_2_e2" width="900"  height="400">
# </p>

# %%
min_value = np.min(data)
max_value = np.max(data)
range_value = max_value - min_value
variance = np.var(data)
std = np.std(data)
cv = std / mean * 100

# %%
print(f"El rango es: {range_value}")
print(f"La varianza es: {variance:.2f}")
print(f"La desviación estándar es: {std:.2f}")
print(f"El coeficiente de variación es: {cv:.2f}")
# Out:
# El rango es: 10.1
# La varianza es: 4.65
# La desviación estándar es: 2.16
# El coeficiente de variación es: 25.43

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=10,color="skyblue", edgecolor="none", kde=True)
plt.title("Distribución de ingresos")
plt.xlabel("Ingresos")
plt.ylabel("Frecuencia")

plt.axvline(mean, color='green', linestyle='--', linewidth=2, label=f'Media = {mean:.2f}')
plt.axvline(mean + std, color='purple', linestyle=':', linewidth=1.5, label=f'+1σ = {mean + std:.2f}')
plt.axvline(mean - std, color='purple', linestyle=':', linewidth=1.5, label=f'-1σ = {mean - std:.2f}')
plt.axvline(min_value, color='red', linestyle='-', linewidth=1.5, label=f'Mínimo = {min_value}')
plt.axvline(max_value, color='red', linestyle='-', linewidth=1.5, label=f'Máximo = {max_value}')
plt.legend()

plt.show()

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 3: Cálculo de medidas de distribución</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, analiza la distribución de los datos. Calcula:
# 1. Asimetría
# 2. Curtosis
# 3. Realiza la comparación con la distribución normal (ver la imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e3.png" alt="sp_2_e3" width="900"  height="400">
# </p>

# %%
from scipy.stats import skew, kurtosis

asimetria = skew(data)
curtosis = kurtosis(data)

# %%
print(f"La asimetría es: {asimetria:.2f}")
print(f"La curtosis es: {curtosis:.2f}")
# Out:
# La asimetría es: 0.14
# La curtosis es: -0.45

# %%
normal = np.random.normal(loc=50, scale=10, size=1000)
normal_asimetria = skew(normal)
normal_curtosis = kurtosis(normal)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
sns.histplot(data, bins=10,color="salmon", edgecolor="black", kde=True, ax=axs[0])
axs[0].set_title("Distribución de ingresos")
sns.histplot(normal, bins=10,color="skyblue", edgecolor="black", kde=True, ax=axs[1])
axs[1].set_title("Distribución normal")
axs[0].text(0.05, 0.95,
            f"Asimetría: {asimetria:.2f}\nCurtosis: {curtosis:.2f}",
            transform=axs[0].transAxes,
            fontsize=10,
            verticalalignment='top',
            bbox=dict(boxstyle="round,pad=0.4", facecolor="white", edgecolor="gray"))
axs[1].text(0.05, 0.95,
            f"Asimetría: {normal_asimetria:.2f}\nCurtosis: {normal_curtosis:.2f}",
            transform=axs[1].transAxes,
            fontsize=10,
            verticalalignment='top',
            bbox=dict(boxstyle="round,pad=0.4", facecolor="white", edgecolor="gray"))
plt.show()

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 4: Cálculo de medidas de percentiles</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, calcula los percentiles de tus datos. Calcula:
# 1. Percentiles
# 2. Deciles
# 3. Cuartiles
# 4. Grafica los anteriores percentiles calculados, sobre la distribución de tus datos (ver la imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e4.png" alt="sp_2_e4" width="900"  height="400">
# </p>

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data, bins=5,color="skyblue", edgecolor="none", kde=True)
plt.title("Distribución de ingresos")
plt.xlabel("Ingresos")
plt.ylabel("Frecuencia")
for i in range(10,101,10):
  plt.axvline(np.percentile(data,i), color='red', linestyle='--', linewidth=1)
  plt.text(np.percentile(data,i),plt.ylim()[1]*0.9,f"D{int(i/10)}",rotation=90,color="gray",fontsize=8,
             verticalalignment='center', horizontalalignment='right')
for i in range(25,101,25):
  plt.axvline(np.percentile(data,i), color='Blue', linestyle='-', linewidth=2)
  plt.text(np.percentile(data,i),plt.ylim()[1]*0.6,f"Q{int(i/25)}",rotation=90,color="gray",fontsize=8,
             verticalalignment='center', horizontalalignment='right')
plt.show()

# %% [markdown]
# ## <span style="color:black;"><strong>Parte 2: Análisis Bivariado</strong></span>

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 5: Análisis de correlación</strong></span>
#
# En esta segunda parte, genera **dos variables** a partir de tú número de cédula y realiza un análisis **bivariado** para calcular la relación entre ellas.
#
# 1. Use los **6 últimos dígitos** de su cédula como base (similar al Ejercicio 1).
# 2. Genere dos variables aleatorias (ejemplo: `ingresos` y `gastos`) con distribución normal, usando esa base como **semilla reproducible**.
# 3. Calcule los coeficientes de correlación de **Pearson** y **Spearman**.
# 4. Grafique las variables analizadas (ver la imagen de ejemplo)
# 5. Interprete los resultados.
#
# <p align="center">
#     <img src="imgs\sp_2_e5.png" alt="sp_2_e5" width="900"  height="400">
# </p>

# %%
from scipy.stats import pearsonr, spearmanr

# %%
np.random.seed(seed)
data1 = np.random.normal(20, 6, 100).round(1)
data2 = np.random.normal((seed % 10) + 2, 2, 100).round(1)

# %%
print(f"La correlación de Pearson es: {pearsonr(data1, data2)[0]:.2f}")
print(f"La correlación de Spearman es: {spearmanr(data1, data2)[0]:.2f}")
# Out:
# La correlación de Pearson es: -0.01
# La correlación de Spearman es: 0.01

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=data1, y=data2, color="salmon")
plt.title("Distribución de ingresos")
plt.xlabel("Ingresos")
plt.ylabel("Gastos")
plt.text(5.5,15.5,
         f"""Pearson: {pearsonr(data1, data2)[0]:.2f}
         \nSpearman: {spearmanr(data1,data2)[0]:.2f} """,
            fontsize=11, verticalalignment='top',
            bbox=dict(boxstyle="round", facecolor="white", edgecolor="gray"))
plt.show()

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 6: Chi-Cuadrado</strong></span>
#
# En esta parte, analiza si existe **asociación estadística** entre dos variables categóricas simuladas a partir de tu número de cédula.
#
# 1. Usa los **6 últimos dígitos** de tu cédula como base para generar una semilla reproducible.
# 2. Simula una muestra de **60 personas** con dos variables categóricas:
#    - `Nivel educativo`: Básico, Medio, Superior.
#    - `Acceso a internet`: Sí, No.
# 3. Crea una **tabla de contingencia** entre ambas variables.
# 4. Aplica la **prueba de Chi cuadrado de independencia**.
# 5. Visualiza la distribución conjunta con un mapa de calor (ver la imagen de con la información de ejemplo).
# 6. Interpreta el resultado.
#
# <p align="center">
#     <img src="imgs\sp_2_e6.png" alt="sp_2_e6" width="900"  height="700">
# </p>

# %%
import pandas as pd
from scipy.stats import chi2_contingency

np.random.seed(seed)
nivel_educativo = np.random.choice(["Básico", "Medio", "Superior"], size=60)
acceso_internet = np.random.choice(["Sí", "No"], size=60)

df = pd.DataFrame({"Nivel educativo": nivel_educativo, "Acceso a internet": acceso_internet})
chi, p, dof, expected = chi2_contingency(pd.crosstab(df["Nivel educativo"], df["Acceso a internet"]))

# %%
fig, axs = plt.subplots(1,2,figsize=(20, 7))
sns.heatmap(pd.crosstab(df["Nivel educativo"], df["Acceso a internet"]), annot=True, cmap="Blues", fmt="d",ax=axs[0])
sns.countplot(data=df, x="Nivel educativo", hue="Acceso a internet", palette="Blues", ax=axs[1])
axs[0].set_title("Tabla de contingencia")
axs[1].set_title("Distribución conjunta")
plt.show()

# %%
print(f"El valor de Chi cuadrado es: {chi:.2f}")
print(f"El valor de p es: {p:.2f}")
# Out:
# El valor de Chi cuadrado es: 1.19
# El valor de p es: 0.55

# %% [markdown]
# # Interpretación
#
# Dado que p >> 0.05, no hay evidencia estadística suficiente para rechazar la hipótesis nula de independencia, por lo que no podemos afirmar que exista una relación entre las variables.
#
# Esto también se puede observar en las gráficas. <br>
# - En la tabla de contingencia podemos ver valores bastante similares en todas las celdas.
# - En la tabla de distribución conjunta no se puede ver una tendencia diferente en el acceso a internet entre los niveles de educación.
