# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Finalizado el procesamiento del dataset original, se obtuvo un conjunto de datos compuesto por 8 columnas predictoras y 1 columna objetivo, a partir de un total inicial de 18 columnas. Asimismo, el número de registros pasó de 12330 a 11713, luego de descartar las muestras consideradas atípicas.
#
# Aunque se realizó el ejercicio de transformación por PCA, finalmente no se generaron nuevas combinaciones de variables ni se utilizaron los componentes principales en el modelo final. El análisis sirvió principalmente como herramienta exploratoria.
#
# Es importante destacar que el dataset original no presentaba valores faltantes, por lo que no fue necesario realizar imputaciones. En cuanto a la transformación, solo fue necesario aplicar una codificación debido a que el dataset final contenía únicamente una variable categórica, además de 3 variables continuas, 3 discretas y 2 binarias (incluyendo la variable objetivo).
#
# En general, el proceso permitió preparar un dataset limpio, consistente y adecuado para la fase de modelado que no corresponde al alcance de este proyecto.
